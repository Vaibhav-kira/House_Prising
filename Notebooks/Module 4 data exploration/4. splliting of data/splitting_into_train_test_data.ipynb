# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Tranformed_Housing_Data_2 = pd.read_csv('/content/drive/MyDrive/Notebooks/Module 4 data exploration /4. splliting of data/Transformed_Housing_Data2.csv')

# %%
Tranformed_Housing_Data_2.head(5)
# Out:
#    Sale_Price  ...  Zipcode_Group_Zipcode_Group_9
# 0    221900.0  ...                              0
# 1    538000.0  ...                              0
# 2    180000.0  ...                              0
# 3    604000.0  ...                              0
# 4    510000.0  ...                              0
#
# [5 rows x 31 columns]

# %%
Y = Tranformed_Housing_Data_2.iloc[:,0]

# %%
X = Tranformed_Housing_Data_2.iloc[:,1:31]
# will give from 1 to 30 ....

# %%
Y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: Sale_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,test_size =  0.3)

# %%
X_train.shape
# Out:
# (15126, 30)

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_test.shape
# Out:
# (6483,)

# %%
Y_train.shape
# Out:
# (15126,)

# %% [markdown]
# # **Feature Scalling**

# %%
X.describe()
# Out:
#        No of Bedrooms  ...  Zipcode_Group_Zipcode_Group_9
# count    21609.000000  ...                   21609.000000
# mean         3.370771  ...                       0.002314
# std          0.929916  ...                       0.048048
# min          0.000000  ...                       0.000000
# 25%          3.000000  ...                       0.000000
# 50%          3.000000  ...                       0.000000
# 75%          4.000000  ...                       0.000000
# max         33.000000  ...                       1.000000
#
# [8 rows x 30 columns]

# %%
from sklearn import preprocessing

# %%
scale = preprocessing.StandardScaler()

# %%
X_train = scale.fit_transform(X_train)

# %%
X_test = scale.fit_transform(X_test)
