# %%
import pandas as pd
import numpy as np
Raw_Housing_Data = pd.read_csv("/content/drive/MyDrive/Notebooks/Module 3/libraries/1. Regression - Module - (Housing Prices).csv")

# %%
# importing the matplotlib library
import matplotlib.pyplot as plt

# %%
# by default X axis = row no.
plt.plot(Raw_Housing_Data['Sale Price'])

# %%
plt.plot(Raw_Housing_Data['Sale Price'], color = 'red')
plt.xlabel("Record number")
plt.ylabel("Sales price")
plt.title("My first graph")
plt.show() # to show the graph

# %%
# condition of houses using pie chart
condition_group = Raw_Housing_Data.groupby('Condition of the House')['ID'].count()
condition_group

# %%
values = (30,1701,14031,5679,172)

# %%
labels =  ('Bad' , 'Excellent' , 'Fair' , 'Good' , 'Okay')

# %%
plt.pie(values,labels = labels)

# %%
plt.bar(labels,values,color = 'blue' , linewidth = 1 , linestyle = 'dashed')
plt.xlabel("Condition of the house")
plt.ylabel("Number of houses")
plt.title("Condition")
plt.show()

# %%
plt.scatter(x = Raw_Housing_Data['Flat Area (in Sqft)'], y = Raw_Housing_Data['Sale Price'],color = 'red')
plt.xlabel("Area of the house")
plt.ylabel("Price of the house")
plt.title("price v/s area")
plt.show()

# %%
plt.scatter(x = Raw_Housing_Data['No of Bathrooms'], y = Raw_Housing_Data['Sale Price'],color = 'red')
plt.xlabel("Number of Bedrooms")
plt.ylabel("Price of the house")
plt.title("number of bedrooms v/s price")
plt.show()

# %%
# age of houses is 3 to 113 etc
plt.hist(Raw_Housing_Data['Age of House (in Years)'],bins = 50,color = 'red')

# %%
# box plot
plt.boxplot(Raw_Housing_Data['Age of House (in Years)'])
