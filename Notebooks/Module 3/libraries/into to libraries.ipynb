# %%
# pandas numpy matplotlib
import pandas

# %%
Raw_Housing_Data = pandas.read_csv('/content/drive/MyDrive/Notebooks/Module 3/libraries/1. Regression - Module - (Housing Prices).csv')

# %%
Raw_Housing_Data
# Out:
#                ID  ... Lot Area after Renovation (in Sqft)
# 0      7129300520  ...                                5650
# 1      6414100192  ...                                7639
# 2      5631500400  ...                                8062
# 3      2487200875  ...                                5000
# 4      1954400510  ...                                7503
# ...           ...  ...                                 ...
# 21608   263000018  ...                                1509
# 21609  6600060120  ...                                7200
# 21610  1523300141  ...                                2007
# 21611   291310100  ...                                1287
# 21612  1523300157  ...                                1357
#
# [21613 rows x 21 columns]
