# %%
import pandas as pd

# %%
Raw_Housing_Data = pd.read_csv("/content/drive/MyDrive/Notebooks/Module 3/libraries/1. Regression - Module - (Housing Prices).csv")

# %%
Raw_Housing_Data
# Out:
#                ID  ... Lot Area after Renovation (in Sqft)
# 0      7129300520  ...                                5650
# 1      6414100192  ...                                7639
# 2      5631500400  ...                                8062
# 3      2487200875  ...                                5000
# 4      1954400510  ...                                7503
# ...           ...  ...                                 ...
# 21608   263000018  ...                                1509
# 21609  6600060120  ...                                7200
# 21610  1523300141  ...                                2007
# 21611   291310100  ...                                1287
# 21612  1523300157  ...                                1357
#
# [21613 rows x 21 columns]

# %%
# 24613 rows( as index start from 0 max index will be 21612) 21 colums ...
# sale price is Dependent Variable / Target value others are house properties or independent vriable
# we would like to build an ML model which will calculate the price of house based on it's properties.

# %%
# To find the data types of variables
Raw_Housing_Data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
Raw_Housing_Data.head(10)
# Out:
#            ID  ... Lot Area after Renovation (in Sqft)
# 0  7129300520  ...                                5650
# 1  6414100192  ...                                7639
# 2  5631500400  ...                                8062
# 3  2487200875  ...                                5000
# 4  1954400510  ...                                7503
# 5  7237550310  ...                              101930
# 6  1321400060  ...                                6819
# 7  2008000270  ...                                9711
# 8  2414600126  ...                                8113
# 9  3793500160  ...                                7570
#
# [10 rows x 21 columns]

# %%
Raw_Housing_Data.tail(10)
# Out:
#                ID  ... Lot Area after Renovation (in Sqft)
# 21603  7852140040  ...                                5731
# 21604  9834201367  ...                                1230
# 21605  3448900210  ...                                6023
# 21606  7936000429  ...                                6200
# 21607  2997800021  ...                                1265
# 21608   263000018  ...                                1509
# 21609  6600060120  ...                                7200
# 21610  1523300141  ...                                2007
# 21611   291310100  ...                                1287
# 21612  1523300157  ...                                1357
#
# [10 rows x 21 columns]
