# %%
import pandas as pd
Raw_Housing_Data = pd.read_csv("/content/drive/MyDrive/Notebooks/Module 3/libraries/1. Regression - Module - (Housing Prices).csv")

# %%
Raw_Housing_Data

# %%
# descriptive anaysis for all the integers
Raw_Housing_Data.describe()

# %%
# Describe all including the object/string.
Raw_Housing_Data.describe(include = 'all')

# %%
# Find info like non-null entries , no. of rows datatype etc.
Raw_Housing_Data.info()
