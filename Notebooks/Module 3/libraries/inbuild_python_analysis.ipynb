# %%
import pandas as pd
Raw_Housing_Data = pd.read_csv("/content/drive/MyDrive/Notebooks/Module 3/libraries/1. Regression - Module - (Housing Prices).csv")

# %%
Raw_Housing_Data
# Out:
#                ID  ... Lot Area after Renovation (in Sqft)
# 0      7129300520  ...                                5650
# 1      6414100192  ...                                7639
# 2      5631500400  ...                                8062
# 3      2487200875  ...                                5000
# 4      1954400510  ...                                7503
# ...           ...  ...                                 ...
# 21608   263000018  ...                                1509
# 21609  6600060120  ...                                7200
# 21610  1523300141  ...                                2007
# 21611   291310100  ...                                1287
# 21612  1523300157  ...                                1357
#
# [21613 rows x 21 columns]

# %%
Raw_Housing_Data['Sale Price'].mean()
# Out:
# 540198.4357443658

# %%
print(Raw_Housing_Data['Sale Price'].max())
print(Raw_Housing_Data['Sale Price'].min())
print(Raw_Housing_Data['Sale Price'].std()) # standart deviation
print(Raw_Housing_Data['Sale Price'].quantile(.25)) # first quantile
print(Raw_Housing_Data['Sale Price'].quantile(.50)) # Second quantile
print(Raw_Housing_Data['Sale Price'].quantile(.75)) # Third quantile
# Out:
# 7700000.0
# 75000.0
# 367388.99446065375
# 321950.0
# 450000.0
# 645000.0

# %%
# displaying all the unique values
print(Raw_Housing_Data['Condition of the House'].unique())
# Out:
# ['Fair' 'Excellent' 'Good' 'Bad' 'Okay']
