# %%
#Integer data type
a = 97
type(a)
# Out:
# int

# %%
#Float number
b = 97.56
type(b)
# Out:
# float

# %%
#complex number
c = 5 + 7j
type(c)
# Out:
# complex

# %%
#string 
d = "vaibhav"
type(d)
e = "Ahuja"
print(d + " " + e)
print(d.upper())
# Out:
# vaibhav Ahuja
# VAIBHAV

# %%
# Lists
l = [68,65.12,0,"vaibhav","Ahuja"]
print(l[3])
l[3] = "Pagal"
l[3]
# Out:
# vaibhav
# 'Pagal'

# %%
# Tuple
t = (0 , 0.22 , "Vaibhav")
t[2]
# Out:
# 'Vaibhav'

# %%
# Set data
s = {0 , 2 , "vaibhav"}
s
# Out:
# {0, 2, 'vaibhav'}

# %%
# dictionaries
dixt = {2 : "Vaibhav", 3 : {0,2,5},5 : (5 , "Vaubhav Ahuja")}
dixt[5]
# Out:
# (5, 'Vaubhav Ahuja')
